# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load('example_abdominal_wall_data/data.npy')

# %%
print(type(data))
print(data.shape)

plt.imshow(data[:,:,1000])
# Out:
# <class 'numpy.ndarray'>
# (115, 192, 2191)
